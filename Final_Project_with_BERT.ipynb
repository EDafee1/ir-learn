# %% [markdown]
# <a href="https://colab.research.google.com/github/EDafee1/ir-learn/blob/main/Final_Project_with_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 60.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 88.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic

# %%
df = pd.read_csv('/content/drive/MyDrive/UDINUS/Information Retrieval/Amazon_Unlocked_Mobile.csv')

# %%
df = df[0:5000]

# %%
docs = df.Reviews.to_list()

# %%
model = BERTopic(verbose=True)

# %%
topics, probs = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# 2023-10-17 13:52:13,758 - BERTopic - Transformed documents to Embeddings
# 2023-10-17 13:52:57,204 - BERTopic - Reduced dimensionality
# 2023-10-17 13:52:57,638 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   1641
# 4        0    136
# 45       1     94
# 38       2     77
# 112      3     73
# ..     ...    ...
# 2      123     11
# 67     124     11
# 100    125     11
# 44     126     11
# 113    127     10
#
# [129 rows x 2 columns]

# %%
model.get_topic_info()
# Out:
#      Topic  Count                                     Name  \
# 0       -1   1641                         -1_the_to_and_is
# 1        0    136                  0_screen_cracked_was_it
# 2        1     94             1_unlocked_locked_unlock_not
# 3        2     77                             2_good_ver__
# 4        3     73                     3_idol_the_phones_of
# ..     ...    ...                                      ...
# 124    123     11    123_pleased_exactly_described_knocked
# 125    124     11            124_wanted_happier_happy_what
# 126    125     11  125_described_revision_exactly_recovers
# 127    126     11      126_liking_dislikes_thinking_gotten
# 128    127     10            127_alcatel_idol_size_skipped
#
#                                         Representation  \
# 0    [the, to, and, is, it, phone, for, this, of, t...
# 1    [screen, cracked, was, it, the, crack, after, ...
# 2    [unlocked, locked, unlock, not, was, said, it,...
# ...

# %%
model.get_topic(0)
# Out:
# [('screen', 0.018732978463491843),
#  ('cracked', 0.013287565740998212),
#  ('was', 0.009945273016165069),
#  ('it', 0.0095992889166495),
#  ('the', 0.009501899398230571),
#  ('crack', 0.009132921224475236),
#  ('after', 0.0079909027766772),
#  ('on', 0.007577845973670123),
#  ('broken', 0.007200457631926304),
#  ('when', 0.007193839220057063)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
